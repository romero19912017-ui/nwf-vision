# %% [markdown]
# # OOD: CIFAR-10 vs SVHN
#
# Train ConvVAE on CIFAR-10. Higher potential = in-distribution. ROC, AUROC.

# %%
# %run ../examples/ood_cifar_svhn.py

# %% [markdown]
# Or: `python examples/ood_cifar_svhn.py --save results/ood.png`
