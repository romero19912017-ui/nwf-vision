# %% [markdown]
# # Active Learning: Uncertainty vs Random
#
# Select by trace(sigma), add to labeled pool. Accuracy vs n_labeled.

# %%
# %run ../examples/active_learning.py

# %% [markdown]
# Or: `python examples/active_learning.py --save results/active.png`
